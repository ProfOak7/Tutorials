# %%
# importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Optional for disabling warnings 
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_excel (r'./Bac_Growth_Curves.xlsx', index_col=0) 
df
# Out:
#         BH1    BH2    BH3   TSB1   TSB2   TSB3   BHI_avg   TSB_avg  BHI_stdev  \
# Time
# 0.0   0.010  0.005  0.020  0.010  0.005  0.010  0.011667  0.008333   0.007638
# 0.5   0.010  0.010  0.020  0.010  0.005  0.010  0.013333  0.008333   0.005774
# 1.0   0.010  0.010  0.020  0.010  0.005  0.010  0.013333  0.008333   0.005774
# 1.5   0.025  0.030  0.035  0.040  0.025  0.025  0.030000  0.030000   0.005000
# 2.0   0.064  0.110  0.095  0.080  0.125  0.060  0.089667  0.088333   0.023459
# 2.5   0.158  0.260  0.198  0.180  0.225  0.119  0.205333  0.174667   0.051394
# 3.0   0.340  0.620  0.380  0.340  0.451  0.231  0.446667  0.340667   0.151438
# 3.5   0.660  2.000  0.699  0.450  0.625  0.375  1.119667  0.483333   0.762640
# 4.0   1.080  2.000  1.100  0.700  0.950  0.500  1.393333  0.716667   0.525484
# 4.5   1.290  2.000  1.400  0.600  2.000  0.580  1.563333  1.060000   0.382143
# 5.0   1.400  2.000  1.500  0.605  2.000  0.600  1.633333  1.068333   0.321455
#
# ...

# %%
df.plot.line(marker = 'o')
# Out:
# <Axes: xlabel='Time'>

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'BHI_avg',color = 'r', marker = 'o', yerr = 'BHI_sem', capsize=5)
df.plot.line(ax = ax, y = 'TSB_avg',color = 'b', marker = 'o', yerr = 'TSB_sem', capsize=5)
ax.set_xlabel("Time (hrs)")
ax.set_ylabel("Absorbance (O.D)")
# Out:
# Text(0, 0.5, 'Absorbance (O.D)')
