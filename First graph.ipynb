# %% [markdown]
# ## Make your first graph in Jupyter notebook

# %% [markdown]
# ### Before beginning, you need to have miniconda installed on your computer.
#
# ### You can find installation instructions for miniconda here: https://docs.conda.io/en/latest/miniconda.html
#
# Next, you will need to access the terminal (command on a PC and terminal on a mac) and create a conda environment. You can create an environment with the name "myfirstenv" by typing the following code in your terminal:

# %%
conda create -n myfirstenv

# %% [markdown]
# Now that the environment is created, you can access it by typing the following command:

# %%
conda activate myfirstenv

# %% [markdown]
# Use the codes below to create your first graph in jupyter notebook... Note that anything that starts with "#" is a comment, which is not part of the initiated code.
#
# Now that you have activated your new environment, you will need to install some packages into it. For this tutorial, you will need to install matplotlib, pandas, seaborn, openpyxl, and jupyter notebook. Install each component by entering the following commands (one at a time):

# %%
conda install matplotlib #This will install matplotlib in your environment

# %%
conda install pandas #This will install pandas in your environment

# %%
conda install openpyxl #This will install openpyxl in your environment

# %%
conda install jupyter notebook #This will install jupyter lab notebook in your environment

# %%
conda install seaborn #This will install seaborn in your environment

# %% [markdown]
# Once complete, you can run jupyter notebook by entering the following command in the terminal:

# %%
Jupyter notebook

# %% [markdown]
# Importing the required module: For this tutorial you are going to import the matplotlib.pyplot package as plt (easier to type). You need to import this package by running the cell below, by either hitting the "run" arrow up above, or hitting: Shift + Enter

# %%
import matplotlib.pyplot as plt #Make sure to run this command by hitting run or hitting shift + enter

# %% [markdown]
# Once the package has been imported, you can successfully make graphs using matplotlib... Let's just make a simple line graph by assigning the following coordinates to x and y:

# %%
#Set the x and y values
x = [0,1,2,3,4,5,6,7]  
y = [0,1,2,3,4,5,6,7]

# %% [markdown]
# Now that we have assigned values to x and y, we can then plot x and y using matplotlib (plt), using the following command:

# %%
plt.plot(x, y) # plotting the points

# %% [markdown]
# That's great, we made our first graph. But what if you want to add x and y axis? Well, we can do that too using matplotlib:

# %%
plt.plot(x, y) # plotting the points 
plt.xlabel('time (hours)') # naming the x axis 
plt.ylabel('time (hours)') # naming the y axis
# Out:
# Text(0, 0.5, 'time (hours)')

# %% [markdown]
# If we want to add a title, we can do that too:

# %%
plt.plot(x, y) # plotting the points 
plt.xlabel('time (hours)') # naming the x axis 
plt.ylabel('time (hours)') # naming the y axis  
plt.title('Time plotted on both x and y axis') # give a title to your graph (note: it automatically puts the title on top) 
plt.show()

# %% [markdown]
# Maybe you want to make a more interesting graph...

# %%
# set the x and y values 
x = [0,8,11,18,24,32,36]  
y = [0.07,3.45,2.96,4.69,0.16,3.73,2.88] 

plt.plot(x, y) # plotting the points 
plt.xlabel('time (hours)') # naming the x axis 
plt.ylabel('Ocean tide (ft)') # naming the y axis  
plt.title('Ocean tide over time') # give a title to your graph (note: it automatically puts the title on top) 
plt.show()
